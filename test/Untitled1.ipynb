# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from IPython.display import HTML

# %%
grad = np.load('/scr2/haipeng/SWIT-1.1/01_fwi/fwi/grad_ite_0005.npy') 
grad[:,:20] = .0
plt.imshow(grad.T, vmin = -600, vmax=600, cmap='seismic')
plt.colorbar()

# %%
grad = np.load('/scr2/haipeng/SWIT-1.1/01_fwi/fwi/vp_ite_0016.npy').reshape(-1, 141) 
plt.imshow(grad.T, vmin = 3500, vmax=4500, cmap='seismic')
plt.colorbar()
